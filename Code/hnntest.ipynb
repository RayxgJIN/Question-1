# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
import csv
import torch, argparse
import autograd.numpy as np
import autograd

from scipy.stats import norm
from utils import leapfrog, to_pickle, from_pickle
import tensorflow as tf
import tensorflow_probability as tfp
from scipy.stats import norm
from scipy.stats import uniform

# %%
input_dim = 2
len_sample = 20
num_samples = 20
test_fraction = 0
timescale = 0.05

# %%
def H(coords):
    #coords = [q,p] in R2
    q, p = np.split(coords,2)
    mu1 = 1.0
    mu2 =-1.0
    sigma = 0.35
    term1 = -np.log(0.5*(np.exp(-(q-mu1)**2/(2*sigma**2)))+0.5*(np.exp(-(q-mu2)**2/(2*sigma**2))))
    H_val = term1 + p**2/2 # Normal PDF
    return H_val

# %%
def dynamics_fn(t, coords):
    dcoords = autograd.grad(H)(coords)
    dic1 = np.split(dcoords,input_dim)
    S = np.concatenate([dic1[int(input_dim/2)]])
    for ii in np.arange(int(input_dim/2)+1,input_dim,1):
        S = np.concatenate([S, dic1[ii]])
    for ii in np.arange(0,int(input_dim/2),1):
        S = np.concatenate([S, -dic1[ii]])
    return S

def get_trajectory(t_span=[0,len_sample], timescale=timescale, y0=None, **kwargs):
    t_eval = np.linspace(t_span[0], t_span[1], int((t_span[1]-t_span[0])/timescale))

    if y0 is None:
        y0 = np.zeros(input_dim)
        for ii in np.arange(0,int(input_dim/2),1):
            y0[ii] = norm(loc=0,scale=1).rvs()
    #lp_ivp = leapfrog(dynamics_fn, t_span, y0,int(timescale*(t_span[1]-t_span[0])), input_dim)
    lp_ivp = leapfrog(dynamics_fn, t_span, y0,int((t_span[1]-t_span[0])/timescale), input_dim)
    dic1 = np.split(lp_ivp, input_dim)
    dydt = [dynamics_fn(None, lp_ivp[:,ii]) for ii in range(0, lp_ivp.shape[1])]
    dydt = np.stack(dydt).T
    ddic1 = np.split(dydt, input_dim)
    return dic1, ddic1, t_eval

# %%
def get_dataset(seed=0, samples=num_samples, test_split=(1.0-test_fraction), **kwargs):
    data = {'meta': locals()}
    # randomly sample inputs
    np.random.seed(seed) #
    xs, dxs = [], []
    index1 = 0

    count1 = 0
    y_init = np.zeros(input_dim)
    for ii in np.arange(0,int(input_dim/2),1):
        y_init[ii] = 0.0
    for ii in np.arange(int(input_dim/2),input_dim,1):
        y_init[ii] = norm(loc=0,scale=1).rvs()

    print('Generating HMC samples for HNN training')

    for s in range(samples):
        print('Sample number ' + str(s+1) + ' of ' + str(samples))
        dic1, ddic1, t = get_trajectory(y0=y_init,**kwargs)
        xs.append(np.stack( [dic1[ii].T.reshape(len(dic1[ii].T)) for ii in np.arange(0,input_dim,1)]).T)
        dxs.append(np.stack( [ddic1[ii].T.reshape(len(ddic1[ii].T)) for ii in np.arange(0,input_dim,1)]).T)
        y_init = np.zeros(input_dim)
        count1 = count1 + 1
        #print(dic1[0].shape)
        for ii in np.arange(0,int(input_dim/2),1):
            y_init[ii] = dic1[ii][0,-1]
        for ii in np.arange(int(input_dim/2),input_dim,1):
            y_init[ii] = norm(loc=0,scale=1).rvs()

    data['coords'] = np.concatenate(xs)
    data['dcoords'] = np.concatenate(dxs).squeeze()

    # make a train/test split
    split_ix = int(len(data['coords']) * test_split)
    split_data = {}
    for k in ['coords', 'dcoords']:
        split_data[k], split_data['test_' + k] = data[k][:split_ix], data[k][split_ix:]
    data = split_data

    # save data
    path = "./data"
    if not os.path.exists(path):
        os.makedirs(path)
    to_pickle(data, path+"/{}.pkl".format("1DGaussian"))

    return data

# %%
dat = get_dataset()
# Out:
# Generating HMC samples for HNN training
# Sample number 1 of 20
# Sample number 2 of 20
# Sample number 3 of 20
# Sample number 4 of 20
# Sample number 5 of 20
# Sample number 6 of 20
# Sample number 7 of 20
# Sample number 8 of 20
# Sample number 9 of 20
# Sample number 10 of 20
# Sample number 11 of 20
# Sample number 12 of 20
# Sample number 13 of 20
# Sample number 14 of 20
# Sample number 15 of 20
# Sample number 16 of 20
# Sample number 17 of 20
# Sample number 18 of 20
# Sample number 19 of 20
# Sample number 20 of 20

# %%
dat['coords'].shape,dat['dcoords'].shape
# Out:
# ((8020, 2), (8020, 2))

# %%
dat["dcoords"]
# Out:
# array([[ 1.76405235, -0.        ],
#        [ 1.87195437,  4.31608098],
#        [ 2.12738862,  5.90128914],
#        ...,
#        [-1.26356053, -2.97798555],
#        [-1.39881515, -2.43219933],
#        [-1.50553403, -1.83655565]])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(dat['coords'][:,0],dat['coords'][:,1],s=1)

# %%
plt.hist(dat['coords'][:,0],bins=100)
plt.show()

# %%
plt.scatter(dat['dcoords'][:,0],dat['dcoords'][:,1],s=1)

# %%
# Define the L-HNN model
class L_HNN(tf.keras.Model):
    def __init__(self):
        super(L_HNN, self).__init__()
        self.hidden_layers = [tf.keras.layers.Dense(100, activation='relu') for _ in range(3)]
        self.output_layer = tf.keras.layers.Dense(input_dim)

    def call(self, inputs):
        x = inputs
        for layer in self.hidden_layers:
            x = layer(x)
        return self.output_layer(x)

    def build(self,input_shape):
        self.hidden_layers[0].build(input_shape)
        input_shape = self.hidden_layers[0].compute_output_shape(input_shape)
        for layer in self.hidden_layers[1:]:
            layer.build(input_shape)
            input_shape = layer.compute_output_shape(input_shape)
        self.output_layer.build(input_shape)
        self.built = True


class HNN(tf.keras.Model):
    '''Learn arbitrary vector fields that are sums of conservative and solenoidal fields'''
    def __init__(self, input_dim, differentiable_model, field_type='solenoidal',
                    baseline=False, assume_canonical_coords=True):
        super(HNN, self).__init__()
        self.baseline = baseline
        self.differentiable_model = differentiable_model
        self.assume_canonical_coords = assume_canonical_coords
        self.M = self.permutation_tensor(input_dim) # Levi-Civita permutation tensor
        self.field_type = field_type

    def call(self, x):
        # traditional forward pass
        if self.baseline:
            return self.differentiable_model(x)

        y = self.differentiable_model(x)
        assert len(y.shape) == 2 and y.shape[1] == input_dim, "Output tensor should have shape [batch_size, 2]"
        answer1 = tf.split(y,2,axis=1) # is it correct?
        return answer1

    #def lfrog_time_derivative(self, x, dt):
    #    return lfrog(fun=self.time_derivative, y0=x, t=0, dt=dt)

    def time_derivative(self, x, t=None, separate_fields=False):
        '''NEURAL ODE-STLE VECTOR FIELD'''
        if self.baseline:
            return self.differentiable_model(x)

        '''NEURAL HAMILTONIAN-STLE VECTOR FIELD'''

        conservative_field = tf.zeros_like(x) # start out with both components set to 0
        solenoidal_field = tf.zeros_like(x)

        with tf.GradientTape() as tape:
            tape.watch(x)
            F1, F2 = self.call(x) # traditional forward pass
            # notion: here autograd is a pytorch function, we change it to tf autograd
            if self.field_type != 'solenoidal':
                F1 = tf.reduce_sum(F1)
                
                dF1 = tape.gradient(F1, x)
                conservative_field = dF1 @ tf.eye(*self.M.shape)

            if self.field_type != 'conservative':
                F2 = tf.reduce_sum(F2)
                dF2 = tape.gradient(F2, x)
                solenoidal_field = dF2 @ tf.transpose(self.M)

        if separate_fields:
            return [conservative_field, solenoidal_field]

        return conservative_field + solenoidal_field

    def permutation_tensor(self,n):
        M = None
        if self.assume_canonical_coords:
            M = tf.eye(n)
            M = tf.concat([M[n//2:], -M[:n//2]],axis=0)
        else:
            '''Constructs the Levi-Civita permutation tensor'''
            M = tf.ones(n,n) # matrix of ones
            M *= 1 - tf.eye(n) # clear diagonals
            M[::2] *= -1 # pattern of signs
            M[:,::2] *= -1

            for i in range(n): # make asymmetric
                for j in range(i+1, n):
                    M[i,j] *= -1
        return M


# Training the L-HNN
def train_l_hnn(coords,dcoords, epochs=3000):
    model_hnn = L_HNN()
    model_hnn.build(input_shape=(None, 2))
    model = HNN(input_dim, model_hnn, field_type='solenoidal', baseline=False, assume_canonical_coords=True)
    

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    num_trainable_params = np.sum([np.prod(var.shape) for var in model.trainable_variables])
    print(f'Number of gradients to be calculated for L-HNN: {num_trainable_params}')

    coords = tf.convert_to_tensor(coords, dtype=tf.float32)
    dcoords = tf.convert_to_tensor(dcoords, dtype=tf.float32)

    for epoch in range(epochs):
        with tf.GradientTape() as tape:
            with tf.GradientTape() as tape2:
                tape2.watch(coords)
                H = model(coords)

                divH = tape2.gradient(H, coords)
                H_q =  divH[:,0]
                H_p =  divH[:,1]

            loss = tf.reduce_mean(tf.square(H_p - dcoords[:,0])) + tf.reduce_mean(tf.square(-H_q - dcoords[:,1]))
            grads = tape.gradient(loss, model.trainable_variables)

            if grads is None or all(g is None for g in grads):
                print(f"No gradients computed at epoch {epoch}. Skipping update.")
                continue  # Skip update if no gradients are computed

            optimizer.apply_gradients(zip(grads, model.trainable_variables))

            if epoch % 100 == 0:
                print(f'Epoch {epoch}, Loss: {loss.numpy()}')

            if epoch % 1000 == 0:
                model.differentiable_model.save_weights("./models/L_HNN.weights.h5")
    
    return model

# %%
model = train_l_hnn(dat['coords'],dat['dcoords'])
# Out:
# Number of gradients to be calculated for L-HNN: 20702
# /Users/kanaboshihikari/opt/anaconda3/envs/tensorflow/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:731: UserWarning: Gradients do not exist for variables ['bias'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# Epoch 0, Loss: 15.117857933044434
# Epoch 100, Loss: 12.818075180053711
# Epoch 200, Loss: 11.311064720153809
# Epoch 300, Loss: 10.768603324890137
# Epoch 400, Loss: 10.331360816955566
# Epoch 500, Loss: 10.031413078308105
# Epoch 600, Loss: 9.87038803100586
# Epoch 700, Loss: 9.976959228515625
# Epoch 800, Loss: 9.916543960571289
# Epoch 900, Loss: 9.868582725524902
# Epoch 1000, Loss: 9.953424453735352
# Epoch 1100, Loss: 9.80166244506836
# Epoch 1200, Loss: 9.813216209411621
# Epoch 1300, Loss: 9.938821792602539
# Epoch 1400, Loss: 9.950407028198242
# Epoch 1500, Loss: 10.31616497039795
# Epoch 1600, Loss: 10.595020294189453
# Epoch 1700, Loss: 10.269003868103027
# Epoch 1800, Loss: 10.502151489257812
# Epoch 1900, Loss: 10.316988945007324
# Epoch 2000, Loss: 10.260856628417969
# Epoch 2100, Loss: 10.352651596069336
# Epoch 2200, Loss: 10.4653902053833
# Epoch 2300, Loss: 10.23008918762207
# Epoch 2400, Loss: 10.17336368560791
# Epoch 2500, Loss: 10.002140045166016
# Epoch 2600, Loss: 10.127823829650879
# Epoch 2700, Loss: 10.32906436920166
# Epoch 2800, Loss: 10.562442779541016
# Epoch 2900, Loss: 10.650595664978027

# %%
model_ = L_HNN()
model_.build(input_shape=(None, 2))
model_.load_weights("./models/L_HNN.weights.h5")
model = HNN(input_dim=input_dim, differentiable_model=model_, field_type='solenoidal', baseline=False, assume_canonical_coords=True)

# %%
chains = 1 # number of Markov chains
N = 5000 # number of samples   
L = 10 # length of each hamiltonian trajectory
burn = 20 # burn-in samples
epsilon = 0.025 # step for time integration

# %%
def integrate_model(model, t_span, y0, n, **kwargs):
    def fun(t, np_x):
        #x = tf.convert_to_tensor( np_x, requires_grad=True, dtype=torch.float32).view(1,input_dim)
        x = tf.convert_to_tensor(np_x.reshape(-1,input_dim), dtype=tf.float32)
        dx = model.time_derivative(x).numpy().reshape(-1)
        return dx
    return leapfrog(fun, t_span, y0, n, input_dim)

# %%
steps = L*int(1/epsilon)
t_span = [0,L]
kwargs = {'t_eval': np.linspace(t_span[0], t_span[1], steps), 'rtol': 1e-10}
hnn_fin = np.zeros((chains,N,int(input_dim/2)))
hnn_accept = np.zeros((chains,N))

y0 = np.zeros(input_dim)
for ss in np.arange(0,chains,1):
    x_req = np.zeros((N,int(input_dim/2)))
    x_req[0,:] = y0[0:int(input_dim/2)]
    accept = np.zeros(N)
    
    for ii in np.arange(0,int(input_dim/2),1):
        y0[ii] = 0.0
    for ii in np.arange(int(input_dim/2),int(input_dim),1):
        y0[ii] = norm(loc=0,scale=1).rvs()
    HNN_sto = np.zeros((input_dim,steps,N))
    for ii in np.arange(0,N,1):
        hnn_ivp = integrate_model(model, t_span, y0, steps-1, **kwargs)
        #hnn_ivp = leapfrog(dynamics_fn, t_span, y0, steps-1, input_dim)
        for sss in range(0,input_dim):
            HNN_sto[sss,:,ii] = hnn_ivp[sss,:]
        yhamil = np.zeros(input_dim)
        for jj in np.arange(0,input_dim,1):
            yhamil[jj] = hnn_ivp[jj,steps-1]
        H_star = H(yhamil)
        H_prev = H(y0)
        alpha = np.minimum(1,np.exp(H_prev - H_star))
        if alpha > uniform().rvs():
            y0[0:int(input_dim/2)] = hnn_ivp[0:int(input_dim/2),steps-1]
            x_req[ii,:] = hnn_ivp[0:int(input_dim/2),steps-1]
            accept[ii] = 1
        else:
            x_req[ii,:] = y0[0:int(input_dim/2)]
        for jj in np.arange(int(input_dim/2),input_dim,1):
            y0[jj] = norm(loc=0,scale=1).rvs()
        print("Sample: "+str(ii)+" Chain: "+str(ss))
    hnn_accept[ss,:] = accept
    hnn_fin[ss,:,:] = x_req

ess_hnn = np.zeros((chains,int(input_dim/2)))
for ss in np.arange(0,chains,1):
    hnn_tf = tf.convert_to_tensor(hnn_fin[ss,burn:N,:])
    ess_hnn[ss,:] = np.array(tfp.mcmc.effective_sample_size(hnn_tf))
# Out:
# Sample: 0 Chain: 0
# Sample: 1 Chain: 0
# Sample: 2 Chain: 0
# Sample: 3 Chain: 0
# Sample: 4 Chain: 0
# Sample: 5 Chain: 0
# Sample: 6 Chain: 0
# Sample: 7 Chain: 0
# Sample: 8 Chain: 0
# Sample: 9 Chain: 0
# Sample: 10 Chain: 0
# Sample: 11 Chain: 0
# Sample: 12 Chain: 0
# Sample: 13 Chain: 0
# Sample: 14 Chain: 0
# Sample: 15 Chain: 0
# Sample: 16 Chain: 0
# Sample: 17 Chain: 0
# Sample: 18 Chain: 0
# Sample: 19 Chain: 0
# Sample: 20 Chain: 0
# Sample: 21 Chain: 0
# Sample: 22 Chain: 0
# Sample: 23 Chain: 0
# Sample: 24 Chain: 0
# Sample: 25 Chain: 0
# Sample: 26 Chain: 0
# Sample: 27 Chain: 0
# Sample: 28 Chain: 0
# Sample: 29 Chain: 0
# Sample: 30 Chain: 0
# Sample: 31 Chain: 0
# Sample: 32 Chain: 0
# Sample: 33 Chain: 0
# Sample: 34 Chain: 0
# Sample: 35 Chain: 0
# Sample: 36 Chain: 0
# Sample: 37 Chain: 0
# Sample: 38 Chain: 0
# Sample: 39 Chain: 0
# Sample: 40 Chain: 0
# Sample: 41 Chain: 0
# Sample: 42 Chain: 0
# Sample: 43 Chain: 0
# Sample: 44 Chain: 0
# Sample: 45 Chain: 0
# Sample: 46 Chain: 0
# Sample: 47 Chain: 0
# Sample: 48 Chain: 0
# Sample: 49 Chain: 0
# Sample: 50 Chain: 0
# Sample: 51 Chain: 0
# Sample: 52 Chain: 0
# Sample: 53 Chain: 0
# Sample: 54 Chain: 0
# Sample: 55 Chain: 0
# Sample: 56 Chain: 0
# Sample: 57 Chain: 0
# Sample: 58 Chain: 0
# Sample: 59 Chain: 0
# Sample: 60 Chain: 0
# Sample: 61 Chain: 0
# Sample: 62 Chain: 0
# Sample: 63 Chain: 0
# Sample: 64 Chain: 0
# Sample: 65 Chain: 0
# Sample: 66 Chain: 0
# Sample: 67 Chain: 0
# Sample: 68 Chain: 0
# Sample: 69 Chain: 0
# Sample: 70 Chain: 0
# Sample: 71 Chain: 0
# Sample: 72 Chain: 0
# Sample: 73 Chain: 0
# Sample: 74 Chain: 0
# Sample: 75 Chain: 0
# Sample: 76 Chain: 0
# Sample: 77 Chain: 0
# Sample: 78 Chain: 0
# Sample: 79 Chain: 0
# Sample: 80 Chain: 0
# Sample: 81 Chain: 0
# Sample: 82 Chain: 0
# Sample: 83 Chain: 0
# Sample: 84 Chain: 0
# Sample: 85 Chain: 0
# Sample: 86 Chain: 0
# Sample: 87 Chain: 0
# Sample: 88 Chain: 0
# Sample: 89 Chain: 0
# Sample: 90 Chain: 0
# Sample: 91 Chain: 0
# Sample: 92 Chain: 0
# Sample: 93 Chain: 0
# Sample: 94 Chain: 0
# Sample: 95 Chain: 0
# Sample: 96 Chain: 0
# Sample: 97 Chain: 0
# Sample: 98 Chain: 0
# Sample: 99 Chain: 0
# Sample: 100 Chain: 0
# Sample: 101 Chain: 0
# Sample: 102 Chain: 0
# Sample: 103 Chain: 0
# Sample: 104 Chain: 0
# Sample: 105 Chain: 0
# Sample: 106 Chain: 0
# Sample: 107 Chain: 0
# Sample: 108 Chain: 0
# Sample: 109 Chain: 0
# Sample: 110 Chain: 0
# Sample: 111 Chain: 0
# Sample: 112 Chain: 0
# Sample: 113 Chain: 0
# Sample: 114 Chain: 0
# Sample: 115 Chain: 0
# Sample: 116 Chain: 0
# Sample: 117 Chain: 0
# Sample: 118 Chain: 0
# Sample: 119 Chain: 0
# Sample: 120 Chain: 0
# Sample: 121 Chain: 0
# Sample: 122 Chain: 0
# Sample: 123 Chain: 0
# Sample: 124 Chain: 0
# Sample: 125 Chain: 0
# Sample: 126 Chain: 0
# Sample: 127 Chain: 0
# Sample: 128 Chain: 0
# Sample: 129 Chain: 0
# Sample: 130 Chain: 0
# Sample: 131 Chain: 0
# Sample: 132 Chain: 0
# Sample: 133 Chain: 0
# Sample: 134 Chain: 0
# Sample: 135 Chain: 0
# Sample: 136 Chain: 0
# Sample: 137 Chain: 0
# Sample: 138 Chain: 0
# Sample: 139 Chain: 0
# Sample: 140 Chain: 0
# Sample: 141 Chain: 0
# Sample: 142 Chain: 0
# Sample: 143 Chain: 0
# Sample: 144 Chain: 0
# Sample: 145 Chain: 0
# Sample: 146 Chain: 0
# Sample: 147 Chain: 0
# Sample: 148 Chain: 0
# Sample: 149 Chain: 0
# Sample: 150 Chain: 0
# Sample: 151 Chain: 0
# Sample: 152 Chain: 0
# Sample: 153 Chain: 0
# Sample: 154 Chain: 0
# Sample: 155 Chain: 0
# Sample: 156 Chain: 0
# Sample: 157 Chain: 0
# Sample: 158 Chain: 0
# Sample: 159 Chain: 0
# Sample: 160 Chain: 0
# Sample: 161 Chain: 0
# Sample: 162 Chain: 0
# Sample: 163 Chain: 0
# Sample: 164 Chain: 0
# Sample: 165 Chain: 0
# Sample: 166 Chain: 0
# Sample: 167 Chain: 0
# Sample: 168 Chain: 0
# Sample: 169 Chain: 0
# Sample: 170 Chain: 0
# Sample: 171 Chain: 0
# Sample: 172 Chain: 0
# Sample: 173 Chain: 0
# Sample: 174 Chain: 0
# Sample: 175 Chain: 0
# Sample: 176 Chain: 0
# Sample: 177 Chain: 0
# Sample: 178 Chain: 0
# Sample: 179 Chain: 0
# Sample: 180 Chain: 0
# Sample: 181 Chain: 0
# Sample: 182 Chain: 0
# Sample: 183 Chain: 0
# Sample: 184 Chain: 0
# Sample: 185 Chain: 0
# Sample: 186 Chain: 0
# Sample: 187 Chain: 0
# Sample: 188 Chain: 0
# Sample: 189 Chain: 0
# Sample: 190 Chain: 0
# Sample: 191 Chain: 0
# Sample: 192 Chain: 0
# Sample: 193 Chain: 0
# Sample: 194 Chain: 0
# Sample: 195 Chain: 0
# Sample: 196 Chain: 0
# Sample: 197 Chain: 0
# Sample: 198 Chain: 0
# Sample: 199 Chain: 0
# Sample: 200 Chain: 0
# Sample: 201 Chain: 0
# Sample: 202 Chain: 0
# Sample: 203 Chain: 0
# Sample: 204 Chain: 0
# Sample: 205 Chain: 0
# Sample: 206 Chain: 0
# Sample: 207 Chain: 0
# Sample: 208 Chain: 0
# Sample: 209 Chain: 0
# Sample: 210 Chain: 0
# Sample: 211 Chain: 0
# Sample: 212 Chain: 0
# Sample: 213 Chain: 0
# Sample: 214 Chain: 0
# Sample: 215 Chain: 0
# Sample: 216 Chain: 0
# Sample: 217 Chain: 0
# Sample: 218 Chain: 0
# Sample: 219 Chain: 0
# Sample: 220 Chain: 0
# Sample: 221 Chain: 0
# Sample: 222 Chain: 0
# Sample: 223 Chain: 0
# Sample: 224 Chain: 0
# Sample: 225 Chain: 0
# Sample: 226 Chain: 0
# Sample: 227 Chain: 0
# Sample: 228 Chain: 0
# Sample: 229 Chain: 0
# Sample: 230 Chain: 0
# Sample: 231 Chain: 0
# Sample: 232 Chain: 0
# Sample: 233 Chain: 0
# Sample: 234 Chain: 0
# Sample: 235 Chain: 0
# Sample: 236 Chain: 0
# Sample: 237 Chain: 0
# Sample: 238 Chain: 0
# Sample: 239 Chain: 0
# Sample: 240 Chain: 0
# Sample: 241 Chain: 0
# Sample: 242 Chain: 0
# Sample: 243 Chain: 0
# Sample: 244 Chain: 0
# Sample: 245 Chain: 0
# Sample: 246 Chain: 0
# Sample: 247 Chain: 0
# Sample: 248 Chain: 0
# Sample: 249 Chain: 0
# Sample: 250 Chain: 0
# Sample: 251 Chain: 0
# Sample: 252 Chain: 0
# Sample: 253 Chain: 0
# Sample: 254 Chain: 0
# Sample: 255 Chain: 0
# Sample: 256 Chain: 0
# Sample: 257 Chain: 0
# Sample: 258 Chain: 0
# Sample: 259 Chain: 0
# Sample: 260 Chain: 0
# Sample: 261 Chain: 0
# Sample: 262 Chain: 0
# Sample: 263 Chain: 0
# Sample: 264 Chain: 0
# Sample: 265 Chain: 0
# Sample: 266 Chain: 0
# Sample: 267 Chain: 0
# Sample: 268 Chain: 0
# Sample: 269 Chain: 0
# Sample: 270 Chain: 0
# Sample: 271 Chain: 0
# Sample: 272 Chain: 0
# Sample: 273 Chain: 0
# Sample: 274 Chain: 0
# Sample: 275 Chain: 0
# Sample: 276 Chain: 0
# Sample: 277 Chain: 0
# Sample: 278 Chain: 0
# Sample: 279 Chain: 0
# Sample: 280 Chain: 0
# Sample: 281 Chain: 0
# Sample: 282 Chain: 0
# Sample: 283 Chain: 0
# Sample: 284 Chain: 0
# Sample: 285 Chain: 0
# Sample: 286 Chain: 0
# Sample: 287 Chain: 0
# Sample: 288 Chain: 0
# Sample: 289 Chain: 0
# Sample: 290 Chain: 0
# Sample: 291 Chain: 0
# Sample: 292 Chain: 0
# Sample: 293 Chain: 0
# Sample: 294 Chain: 0
# Sample: 295 Chain: 0
# Sample: 296 Chain: 0
# Sample: 297 Chain: 0
# Sample: 298 Chain: 0
# Sample: 299 Chain: 0
# Sample: 300 Chain: 0
# Sample: 301 Chain: 0
# Sample: 302 Chain: 0
# Sample: 303 Chain: 0
# Sample: 304 Chain: 0
# Sample: 305 Chain: 0
# Sample: 306 Chain: 0
# Sample: 307 Chain: 0
# Sample: 308 Chain: 0
# Sample: 309 Chain: 0
# Sample: 310 Chain: 0
# Sample: 311 Chain: 0
# Sample: 312 Chain: 0
# Sample: 313 Chain: 0
# Sample: 314 Chain: 0
# Sample: 315 Chain: 0
# Sample: 316 Chain: 0
# Sample: 317 Chain: 0
# Sample: 318 Chain: 0
# Sample: 319 Chain: 0
# Sample: 320 Chain: 0
# Sample: 321 Chain: 0
# Sample: 322 Chain: 0
# Sample: 323 Chain: 0
# Sample: 324 Chain: 0
# Sample: 325 Chain: 0
# Sample: 326 Chain: 0
# Sample: 327 Chain: 0
# Sample: 328 Chain: 0
# Sample: 329 Chain: 0
# Sample: 330 Chain: 0
# Sample: 331 Chain: 0
# Sample: 332 Chain: 0
# Sample: 333 Chain: 0
# Sample: 334 Chain: 0
# Sample: 335 Chain: 0
# Sample: 336 Chain: 0
# Sample: 337 Chain: 0
# Sample: 338 Chain: 0
# Sample: 339 Chain: 0
# Sample: 340 Chain: 0
# Sample: 341 Chain: 0
# Sample: 342 Chain: 0
# Sample: 343 Chain: 0
# Sample: 344 Chain: 0
# Sample: 345 Chain: 0
# Sample: 346 Chain: 0
# Sample: 347 Chain: 0
# Sample: 348 Chain: 0
# Sample: 349 Chain: 0
# Sample: 350 Chain: 0
# Sample: 351 Chain: 0
# Sample: 352 Chain: 0
# Sample: 353 Chain: 0
# Sample: 354 Chain: 0
# Sample: 355 Chain: 0
# Sample: 356 Chain: 0
# Sample: 357 Chain: 0
# Sample: 358 Chain: 0
# Sample: 359 Chain: 0
# Sample: 360 Chain: 0
# Sample: 361 Chain: 0
# Sample: 362 Chain: 0
# Sample: 363 Chain: 0
# Sample: 364 Chain: 0
# Sample: 365 Chain: 0
# Sample: 366 Chain: 0
# Sample: 367 Chain: 0
# Sample: 368 Chain: 0
# Sample: 369 Chain: 0
# Sample: 370 Chain: 0
# Sample: 371 Chain: 0
# Sample: 372 Chain: 0
# Sample: 373 Chain: 0
# Sample: 374 Chain: 0
# Sample: 375 Chain: 0
# Sample: 376 Chain: 0
# Sample: 377 Chain: 0
# Sample: 378 Chain: 0
# Sample: 379 Chain: 0
# Sample: 380 Chain: 0
# Sample: 381 Chain: 0
# Sample: 382 Chain: 0
# Sample: 383 Chain: 0
# Sample: 384 Chain: 0
# Sample: 385 Chain: 0
# Sample: 386 Chain: 0
# Sample: 387 Chain: 0
# Sample: 388 Chain: 0
# Sample: 389 Chain: 0
# Sample: 390 Chain: 0
# Sample: 391 Chain: 0
# Sample: 392 Chain: 0
# Sample: 393 Chain: 0
# Sample: 394 Chain: 0
# Sample: 395 Chain: 0
# Sample: 396 Chain: 0
# Sample: 397 Chain: 0
# Sample: 398 Chain: 0
# Sample: 399 Chain: 0
# Sample: 400 Chain: 0
# Sample: 401 Chain: 0
# Sample: 402 Chain: 0
# Sample: 403 Chain: 0
# Sample: 404 Chain: 0
# Sample: 405 Chain: 0
# Sample: 406 Chain: 0
# Sample: 407 Chain: 0
# Sample: 408 Chain: 0
# Sample: 409 Chain: 0
# Sample: 410 Chain: 0
# Sample: 411 Chain: 0
# Sample: 412 Chain: 0
# Sample: 413 Chain: 0
# Sample: 414 Chain: 0
# Sample: 415 Chain: 0
# Sample: 416 Chain: 0
# Sample: 417 Chain: 0
# Sample: 418 Chain: 0
# Sample: 419 Chain: 0
# Sample: 420 Chain: 0
# Sample: 421 Chain: 0
# Sample: 422 Chain: 0
# Sample: 423 Chain: 0
# Sample: 424 Chain: 0
# Sample: 425 Chain: 0
# Sample: 426 Chain: 0
# Sample: 427 Chain: 0
# Sample: 428 Chain: 0
# Sample: 429 Chain: 0
# Sample: 430 Chain: 0
# Sample: 431 Chain: 0
# Sample: 432 Chain: 0
# Sample: 433 Chain: 0
# Sample: 434 Chain: 0
# Sample: 435 Chain: 0
# Sample: 436 Chain: 0
# Sample: 437 Chain: 0
# Sample: 438 Chain: 0
# Sample: 439 Chain: 0
# Sample: 440 Chain: 0
# Sample: 441 Chain: 0
# Sample: 442 Chain: 0
# Sample: 443 Chain: 0
# Sample: 444 Chain: 0
# Sample: 445 Chain: 0
# Sample: 446 Chain: 0
# Sample: 447 Chain: 0
# Sample: 448 Chain: 0
# Sample: 449 Chain: 0
# Sample: 450 Chain: 0
# Sample: 451 Chain: 0
# Sample: 452 Chain: 0
# Sample: 453 Chain: 0
# Sample: 454 Chain: 0
# Sample: 455 Chain: 0
# Sample: 456 Chain: 0
# Sample: 457 Chain: 0
# Sample: 458 Chain: 0
# Sample: 459 Chain: 0
# Sample: 460 Chain: 0
# Sample: 461 Chain: 0
# Sample: 462 Chain: 0
# Sample: 463 Chain: 0
# Sample: 464 Chain: 0
# Sample: 465 Chain: 0
# Sample: 466 Chain: 0
# Sample: 467 Chain: 0
# Sample: 468 Chain: 0
# Sample: 469 Chain: 0
# Sample: 470 Chain: 0
# Sample: 471 Chain: 0
# Sample: 472 Chain: 0
# Sample: 473 Chain: 0
# Sample: 474 Chain: 0
# Sample: 475 Chain: 0
# Sample: 476 Chain: 0
# Sample: 477 Chain: 0
# Sample: 478 Chain: 0
# Sample: 479 Chain: 0
# Sample: 480 Chain: 0
# Sample: 481 Chain: 0
# Sample: 482 Chain: 0
# Sample: 483 Chain: 0
# Sample: 484 Chain: 0
# Sample: 485 Chain: 0
# Sample: 486 Chain: 0
# Sample: 487 Chain: 0
# Sample: 488 Chain: 0
# Sample: 489 Chain: 0
# Sample: 490 Chain: 0
# Sample: 491 Chain: 0
# Sample: 492 Chain: 0
# Sample: 493 Chain: 0
# Sample: 494 Chain: 0
# Sample: 495 Chain: 0
# Sample: 496 Chain: 0
# Sample: 497 Chain: 0
# Sample: 498 Chain: 0
# Sample: 499 Chain: 0
# Sample: 500 Chain: 0
# Sample: 501 Chain: 0
# Sample: 502 Chain: 0
# Sample: 503 Chain: 0
# Sample: 504 Chain: 0
# Sample: 505 Chain: 0
# Sample: 506 Chain: 0
# Sample: 507 Chain: 0
# Sample: 508 Chain: 0
# Sample: 509 Chain: 0
# Sample: 510 Chain: 0
# Sample: 511 Chain: 0
# Sample: 512 Chain: 0
# Sample: 513 Chain: 0
# Sample: 514 Chain: 0
# Sample: 515 Chain: 0
# Sample: 516 Chain: 0
# Sample: 517 Chain: 0
# Sample: 518 Chain: 0
# Sample: 519 Chain: 0
# Sample: 520 Chain: 0
# Sample: 521 Chain: 0
# Sample: 522 Chain: 0
# Sample: 523 Chain: 0
# Sample: 524 Chain: 0
# Sample: 525 Chain: 0
# Sample: 526 Chain: 0
# Sample: 527 Chain: 0
# Sample: 528 Chain: 0
# Sample: 529 Chain: 0
# Sample: 530 Chain: 0
# Sample: 531 Chain: 0
# Sample: 532 Chain: 0
# Sample: 533 Chain: 0
# Sample: 534 Chain: 0
# Sample: 535 Chain: 0
# Sample: 536 Chain: 0
# Sample: 537 Chain: 0
# Sample: 538 Chain: 0
# Sample: 539 Chain: 0
# Sample: 540 Chain: 0
# Sample: 541 Chain: 0
# Sample: 542 Chain: 0
# Sample: 543 Chain: 0
# Sample: 544 Chain: 0
# Sample: 545 Chain: 0
# Sample: 546 Chain: 0
# Sample: 547 Chain: 0
# Sample: 548 Chain: 0
# Sample: 549 Chain: 0
# Sample: 550 Chain: 0
# Sample: 551 Chain: 0
# Sample: 552 Chain: 0
# Sample: 553 Chain: 0
# Sample: 554 Chain: 0
# Sample: 555 Chain: 0
# Sample: 556 Chain: 0
# Sample: 557 Chain: 0
# Sample: 558 Chain: 0
# Sample: 559 Chain: 0
# Sample: 560 Chain: 0
# Sample: 561 Chain: 0
# Sample: 562 Chain: 0
# Sample: 563 Chain: 0
# Sample: 564 Chain: 0
# Sample: 565 Chain: 0
# Sample: 566 Chain: 0
# Sample: 567 Chain: 0
# Sample: 568 Chain: 0
# Sample: 569 Chain: 0
# Sample: 570 Chain: 0
# Sample: 571 Chain: 0
# Sample: 572 Chain: 0
# Sample: 573 Chain: 0
# Sample: 574 Chain: 0
# Sample: 575 Chain: 0
# Sample: 576 Chain: 0
# Sample: 577 Chain: 0
# Sample: 578 Chain: 0
# Sample: 579 Chain: 0
# Sample: 580 Chain: 0
# Sample: 581 Chain: 0
# Sample: 582 Chain: 0
# Sample: 583 Chain: 0
# Sample: 584 Chain: 0
# Sample: 585 Chain: 0
# Sample: 586 Chain: 0
# Sample: 587 Chain: 0
# Sample: 588 Chain: 0
# Sample: 589 Chain: 0
# Sample: 590 Chain: 0
# Sample: 591 Chain: 0
# Sample: 592 Chain: 0
# Sample: 593 Chain: 0
# Sample: 594 Chain: 0
# Sample: 595 Chain: 0
# Sample: 596 Chain: 0
# Sample: 597 Chain: 0
# Sample: 598 Chain: 0
# Sample: 599 Chain: 0
# Sample: 600 Chain: 0
# Sample: 601 Chain: 0
# Sample: 602 Chain: 0
# Sample: 603 Chain: 0
# Sample: 604 Chain: 0
# Sample: 605 Chain: 0
# Sample: 606 Chain: 0
# Sample: 607 Chain: 0
# Sample: 608 Chain: 0
# Sample: 609 Chain: 0
# Sample: 610 Chain: 0
# Sample: 611 Chain: 0
# Sample: 612 Chain: 0
# Sample: 613 Chain: 0
# Sample: 614 Chain: 0
# Sample: 615 Chain: 0
# Sample: 616 Chain: 0
# Sample: 617 Chain: 0
# Sample: 618 Chain: 0
# Sample: 619 Chain: 0
# Sample: 620 Chain: 0
# Sample: 621 Chain: 0
# Sample: 622 Chain: 0
# Sample: 623 Chain: 0
# Sample: 624 Chain: 0
# Sample: 625 Chain: 0
# Sample: 626 Chain: 0
# Sample: 627 Chain: 0
# Sample: 628 Chain: 0
# Sample: 629 Chain: 0
# Sample: 630 Chain: 0
# Sample: 631 Chain: 0
# Sample: 632 Chain: 0
# Sample: 633 Chain: 0
# Sample: 634 Chain: 0
# Sample: 635 Chain: 0
# Sample: 636 Chain: 0
# Sample: 637 Chain: 0
# Sample: 638 Chain: 0
# Sample: 639 Chain: 0
# Sample: 640 Chain: 0
# Sample: 641 Chain: 0
# Sample: 642 Chain: 0
# Sample: 643 Chain: 0
# Sample: 644 Chain: 0
# Sample: 645 Chain: 0
# Sample: 646 Chain: 0
# Sample: 647 Chain: 0
# Sample: 648 Chain: 0
# Sample: 649 Chain: 0
# Sample: 650 Chain: 0
# Sample: 651 Chain: 0
# Sample: 652 Chain: 0
# Sample: 653 Chain: 0
# Sample: 654 Chain: 0
# Sample: 655 Chain: 0
# Sample: 656 Chain: 0
# Sample: 657 Chain: 0
# Sample: 658 Chain: 0
# Sample: 659 Chain: 0
# Sample: 660 Chain: 0
# Sample: 661 Chain: 0
# Sample: 662 Chain: 0
# Sample: 663 Chain: 0
# Sample: 664 Chain: 0
# Sample: 665 Chain: 0
# Sample: 666 Chain: 0
# Sample: 667 Chain: 0
# Sample: 668 Chain: 0
# Sample: 669 Chain: 0
# Sample: 670 Chain: 0
# Sample: 671 Chain: 0
# Sample: 672 Chain: 0
# Sample: 673 Chain: 0
# Sample: 674 Chain: 0
# Sample: 675 Chain: 0
# Sample: 676 Chain: 0
# Sample: 677 Chain: 0
# Sample: 678 Chain: 0
# Sample: 679 Chain: 0
# Sample: 680 Chain: 0
# Sample: 681 Chain: 0
# Sample: 682 Chain: 0
# Sample: 683 Chain: 0
# Sample: 684 Chain: 0
# Sample: 685 Chain: 0
# Sample: 686 Chain: 0
# Sample: 687 Chain: 0
# Sample: 688 Chain: 0
# Sample: 689 Chain: 0
# Sample: 690 Chain: 0
# Sample: 691 Chain: 0
# Sample: 692 Chain: 0
# Sample: 693 Chain: 0
# Sample: 694 Chain: 0
# Sample: 695 Chain: 0
# Sample: 696 Chain: 0
# Sample: 697 Chain: 0
# Sample: 698 Chain: 0
# Sample: 699 Chain: 0
# Sample: 700 Chain: 0
# Sample: 701 Chain: 0
# Sample: 702 Chain: 0
# Sample: 703 Chain: 0
# Sample: 704 Chain: 0
# Sample: 705 Chain: 0
# Sample: 706 Chain: 0
# Sample: 707 Chain: 0
# Sample: 708 Chain: 0
# Sample: 709 Chain: 0
# Sample: 710 Chain: 0
# Sample: 711 Chain: 0
# Sample: 712 Chain: 0
# Sample: 713 Chain: 0
# Sample: 714 Chain: 0
# Sample: 715 Chain: 0
# Sample: 716 Chain: 0
# Sample: 717 Chain: 0
# Sample: 718 Chain: 0
# Sample: 719 Chain: 0
# Sample: 720 Chain: 0
# Sample: 721 Chain: 0
# Sample: 722 Chain: 0
# Sample: 723 Chain: 0
# Sample: 724 Chain: 0
# Sample: 725 Chain: 0
# Sample: 726 Chain: 0
# Sample: 727 Chain: 0
# Sample: 728 Chain: 0
# Sample: 729 Chain: 0
# Sample: 730 Chain: 0
# Sample: 731 Chain: 0
# Sample: 732 Chain: 0
# Sample: 733 Chain: 0
# Sample: 734 Chain: 0
# Sample: 735 Chain: 0
# Sample: 736 Chain: 0
# Sample: 737 Chain: 0
# Sample: 738 Chain: 0
# Sample: 739 Chain: 0
# Sample: 740 Chain: 0
# Sample: 741 Chain: 0
# Sample: 742 Chain: 0
# Sample: 743 Chain: 0
# Sample: 744 Chain: 0
# Sample: 745 Chain: 0
# Sample: 746 Chain: 0
# Sample: 747 Chain: 0
# Sample: 748 Chain: 0
# Sample: 749 Chain: 0
# Sample: 750 Chain: 0
# Sample: 751 Chain: 0
# Sample: 752 Chain: 0
# Sample: 753 Chain: 0
# Sample: 754 Chain: 0
# Sample: 755 Chain: 0
# Sample: 756 Chain: 0
# Sample: 757 Chain: 0
# Sample: 758 Chain: 0
# Sample: 759 Chain: 0
# Sample: 760 Chain: 0
# Sample: 761 Chain: 0
# Sample: 762 Chain: 0
# Sample: 763 Chain: 0
# Sample: 764 Chain: 0
# Sample: 765 Chain: 0
# Sample: 766 Chain: 0
# Sample: 767 Chain: 0
# Sample: 768 Chain: 0
# Sample: 769 Chain: 0
# Sample: 770 Chain: 0
# Sample: 771 Chain: 0
# Sample: 772 Chain: 0
# Sample: 773 Chain: 0
# Sample: 774 Chain: 0
# Sample: 775 Chain: 0
# Sample: 776 Chain: 0
# Sample: 777 Chain: 0
# Sample: 778 Chain: 0
# Sample: 779 Chain: 0
# Sample: 780 Chain: 0
# Sample: 781 Chain: 0
# Sample: 782 Chain: 0
# Sample: 783 Chain: 0
# Sample: 784 Chain: 0
# Sample: 785 Chain: 0
# Sample: 786 Chain: 0
# Sample: 787 Chain: 0
# Sample: 788 Chain: 0
# Sample: 789 Chain: 0
# Sample: 790 Chain: 0
# Sample: 791 Chain: 0
# Sample: 792 Chain: 0
# Sample: 793 Chain: 0
# Sample: 794 Chain: 0
# Sample: 795 Chain: 0
# Sample: 796 Chain: 0
# Sample: 797 Chain: 0
# Sample: 798 Chain: 0
# Sample: 799 Chain: 0
# Sample: 800 Chain: 0
# Sample: 801 Chain: 0
# Sample: 802 Chain: 0
# Sample: 803 Chain: 0
# Sample: 804 Chain: 0
# Sample: 805 Chain: 0
# Sample: 806 Chain: 0
# Sample: 807 Chain: 0
# Sample: 808 Chain: 0
# Sample: 809 Chain: 0
# Sample: 810 Chain: 0
# Sample: 811 Chain: 0
# Sample: 812 Chain: 0
# Sample: 813 Chain: 0
# Sample: 814 Chain: 0
# Sample: 815 Chain: 0
# Sample: 816 Chain: 0
# Sample: 817 Chain: 0
# Sample: 818 Chain: 0
# Sample: 819 Chain: 0
# Sample: 820 Chain: 0
# Sample: 821 Chain: 0
# Sample: 822 Chain: 0
# Sample: 823 Chain: 0
# Sample: 824 Chain: 0
# Sample: 825 Chain: 0
# Sample: 826 Chain: 0
# Sample: 827 Chain: 0
# Sample: 828 Chain: 0
# Sample: 829 Chain: 0
# Sample: 830 Chain: 0
# Sample: 831 Chain: 0
# Sample: 832 Chain: 0
# Sample: 833 Chain: 0
# Sample: 834 Chain: 0
# Sample: 835 Chain: 0
# Sample: 836 Chain: 0
# Sample: 837 Chain: 0
# Sample: 838 Chain: 0
# Sample: 839 Chain: 0
# Sample: 840 Chain: 0
# Sample: 841 Chain: 0
# Sample: 842 Chain: 0
# Sample: 843 Chain: 0
# Sample: 844 Chain: 0
# Sample: 845 Chain: 0
# Sample: 846 Chain: 0
# Sample: 847 Chain: 0
# Sample: 848 Chain: 0
# Sample: 849 Chain: 0
# Sample: 850 Chain: 0
# Sample: 851 Chain: 0
# Sample: 852 Chain: 0
# Sample: 853 Chain: 0
# Sample: 854 Chain: 0
# Sample: 855 Chain: 0
# Sample: 856 Chain: 0
# Sample: 857 Chain: 0
# Sample: 858 Chain: 0
# Sample: 859 Chain: 0
# Sample: 860 Chain: 0
# Sample: 861 Chain: 0
# Sample: 862 Chain: 0
# Sample: 863 Chain: 0
# Sample: 864 Chain: 0
# Sample: 865 Chain: 0
# Sample: 866 Chain: 0
# Sample: 867 Chain: 0
# Sample: 868 Chain: 0
# Sample: 869 Chain: 0
# Sample: 870 Chain: 0
# Sample: 871 Chain: 0
# Sample: 872 Chain: 0
# Sample: 873 Chain: 0
# Sample: 874 Chain: 0
# Sample: 875 Chain: 0
# Sample: 876 Chain: 0
# Sample: 877 Chain: 0
# Sample: 878 Chain: 0
# Sample: 879 Chain: 0
# Sample: 880 Chain: 0
# Sample: 881 Chain: 0
# Sample: 882 Chain: 0
# Sample: 883 Chain: 0
# Sample: 884 Chain: 0
# Sample: 885 Chain: 0
# Sample: 886 Chain: 0
# Sample: 887 Chain: 0
# Sample: 888 Chain: 0
# Sample: 889 Chain: 0
# Sample: 890 Chain: 0
# Sample: 891 Chain: 0
# Sample: 892 Chain: 0
# Sample: 893 Chain: 0
# Sample: 894 Chain: 0
# Sample: 895 Chain: 0
# Sample: 896 Chain: 0
# Sample: 897 Chain: 0
# Sample: 898 Chain: 0
# Sample: 899 Chain: 0
# Sample: 900 Chain: 0
# Sample: 901 Chain: 0
# Sample: 902 Chain: 0
# Sample: 903 Chain: 0
# Sample: 904 Chain: 0
# Sample: 905 Chain: 0
# Sample: 906 Chain: 0
# Sample: 907 Chain: 0
# Sample: 908 Chain: 0
# Sample: 909 Chain: 0
# Sample: 910 Chain: 0
# Sample: 911 Chain: 0
# Sample: 912 Chain: 0
# Sample: 913 Chain: 0
# Sample: 914 Chain: 0
# Sample: 915 Chain: 0
# Sample: 916 Chain: 0
# Sample: 917 Chain: 0
# Sample: 918 Chain: 0
# Sample: 919 Chain: 0
# Sample: 920 Chain: 0
# Sample: 921 Chain: 0
# Sample: 922 Chain: 0
# Sample: 923 Chain: 0
# Sample: 924 Chain: 0
# Sample: 925 Chain: 0
# Sample: 926 Chain: 0
# Sample: 927 Chain: 0
# Sample: 928 Chain: 0
# Sample: 929 Chain: 0
# Sample: 930 Chain: 0
# Sample: 931 Chain: 0
# Sample: 932 Chain: 0
# Sample: 933 Chain: 0
# Sample: 934 Chain: 0
# Sample: 935 Chain: 0
# Sample: 936 Chain: 0
# Sample: 937 Chain: 0
# Sample: 938 Chain: 0
# Sample: 939 Chain: 0
# Sample: 940 Chain: 0
# Sample: 941 Chain: 0
# Sample: 942 Chain: 0
# Sample: 943 Chain: 0
# Sample: 944 Chain: 0
# Sample: 945 Chain: 0
# Sample: 946 Chain: 0
# Sample: 947 Chain: 0
# Sample: 948 Chain: 0
# Sample: 949 Chain: 0
# Sample: 950 Chain: 0
# Sample: 951 Chain: 0
# Sample: 952 Chain: 0
# Sample: 953 Chain: 0
# Sample: 954 Chain: 0
# Sample: 955 Chain: 0
# Sample: 956 Chain: 0
# Sample: 957 Chain: 0
# Sample: 958 Chain: 0
# Sample: 959 Chain: 0
# Sample: 960 Chain: 0
# Sample: 961 Chain: 0
# Sample: 962 Chain: 0
# Sample: 963 Chain: 0
# Sample: 964 Chain: 0
# Sample: 965 Chain: 0
# Sample: 966 Chain: 0
# Sample: 967 Chain: 0
# Sample: 968 Chain: 0
# Sample: 969 Chain: 0
# Sample: 970 Chain: 0
# Sample: 971 Chain: 0
# Sample: 972 Chain: 0
# Sample: 973 Chain: 0
# Sample: 974 Chain: 0
# Sample: 975 Chain: 0
# Sample: 976 Chain: 0
# Sample: 977 Chain: 0
# Sample: 978 Chain: 0
# Sample: 979 Chain: 0
# Sample: 980 Chain: 0
# Sample: 981 Chain: 0
# Sample: 982 Chain: 0
# Sample: 983 Chain: 0
# Sample: 984 Chain: 0
# Sample: 985 Chain: 0
# Sample: 986 Chain: 0
# Sample: 987 Chain: 0
# Sample: 988 Chain: 0
# Sample: 989 Chain: 0
# Sample: 990 Chain: 0
# Sample: 991 Chain: 0
# Sample: 992 Chain: 0
# Sample: 993 Chain: 0
# Sample: 994 Chain: 0
# Sample: 995 Chain: 0
# Sample: 996 Chain: 0
# Sample: 997 Chain: 0
# Sample: 998 Chain: 0
# Sample: 999 Chain: 0
# Sample: 1000 Chain: 0
# Sample: 1001 Chain: 0
# Sample: 1002 Chain: 0
# Sample: 1003 Chain: 0
# Sample: 1004 Chain: 0
# Sample: 1005 Chain: 0
# Sample: 1006 Chain: 0
# Sample: 1007 Chain: 0
# Sample: 1008 Chain: 0
# Sample: 1009 Chain: 0
# Sample: 1010 Chain: 0
# Sample: 1011 Chain: 0
# Sample: 1012 Chain: 0
# Sample: 1013 Chain: 0
# Sample: 1014 Chain: 0
# Sample: 1015 Chain: 0
# Sample: 1016 Chain: 0
# Sample: 1017 Chain: 0
# Sample: 1018 Chain: 0
# Sample: 1019 Chain: 0
# Sample: 1020 Chain: 0
# Sample: 1021 Chain: 0
# Sample: 1022 Chain: 0
# Sample: 1023 Chain: 0
# Sample: 1024 Chain: 0
# Sample: 1025 Chain: 0
# Sample: 1026 Chain: 0
# Sample: 1027 Chain: 0
# Sample: 1028 Chain: 0
# Sample: 1029 Chain: 0
# Sample: 1030 Chain: 0
# Sample: 1031 Chain: 0
# Sample: 1032 Chain: 0
# Sample: 1033 Chain: 0
# Sample: 1034 Chain: 0
# Sample: 1035 Chain: 0
# Sample: 1036 Chain: 0
# Sample: 1037 Chain: 0
# Sample: 1038 Chain: 0
# Sample: 1039 Chain: 0
# Sample: 1040 Chain: 0
# Sample: 1041 Chain: 0
# Sample: 1042 Chain: 0
# Sample: 1043 Chain: 0
# Sample: 1044 Chain: 0
# Sample: 1045 Chain: 0
# Sample: 1046 Chain: 0
# Sample: 1047 Chain: 0
# Sample: 1048 Chain: 0
# Sample: 1049 Chain: 0
# Sample: 1050 Chain: 0
# Sample: 1051 Chain: 0
# Sample: 1052 Chain: 0
# Sample: 1053 Chain: 0
# Sample: 1054 Chain: 0
# Sample: 1055 Chain: 0
# Sample: 1056 Chain: 0
# Sample: 1057 Chain: 0
# Sample: 1058 Chain: 0
# Sample: 1059 Chain: 0
# Sample: 1060 Chain: 0
# Sample: 1061 Chain: 0
# Sample: 1062 Chain: 0
# Sample: 1063 Chain: 0
# Sample: 1064 Chain: 0
# Sample: 1065 Chain: 0
# Sample: 1066 Chain: 0
# Sample: 1067 Chain: 0
# Sample: 1068 Chain: 0
# Sample: 1069 Chain: 0
# Sample: 1070 Chain: 0
# Sample: 1071 Chain: 0
# Sample: 1072 Chain: 0
# Sample: 1073 Chain: 0
# Sample: 1074 Chain: 0
# Sample: 1075 Chain: 0
# Sample: 1076 Chain: 0
# Sample: 1077 Chain: 0
# Sample: 1078 Chain: 0
# Sample: 1079 Chain: 0
# Sample: 1080 Chain: 0
# Sample: 1081 Chain: 0
# Sample: 1082 Chain: 0
# Sample: 1083 Chain: 0
# Sample: 1084 Chain: 0
# Sample: 1085 Chain: 0
# Sample: 1086 Chain: 0
# Sample: 1087 Chain: 0
# Sample: 1088 Chain: 0
# Sample: 1089 Chain: 0
# Sample: 1090 Chain: 0
# Sample: 1091 Chain: 0
# Sample: 1092 Chain: 0
# Sample: 1093 Chain: 0
# Sample: 1094 Chain: 0
# Sample: 1095 Chain: 0
# Sample: 1096 Chain: 0
# Sample: 1097 Chain: 0
# Sample: 1098 Chain: 0
# Sample: 1099 Chain: 0
# Sample: 1100 Chain: 0
# Sample: 1101 Chain: 0
# Sample: 1102 Chain: 0
# Sample: 1103 Chain: 0
# Sample: 1104 Chain: 0
# Sample: 1105 Chain: 0
# Sample: 1106 Chain: 0
# Sample: 1107 Chain: 0
# Sample: 1108 Chain: 0
# Sample: 1109 Chain: 0
# Sample: 1110 Chain: 0
# Sample: 1111 Chain: 0
# Sample: 1112 Chain: 0
# Sample: 1113 Chain: 0
# Sample: 1114 Chain: 0
# Sample: 1115 Chain: 0
# Sample: 1116 Chain: 0
# Sample: 1117 Chain: 0
# Sample: 1118 Chain: 0
# Sample: 1119 Chain: 0
# Sample: 1120 Chain: 0
# Sample: 1121 Chain: 0
# Sample: 1122 Chain: 0
# Sample: 1123 Chain: 0
# Sample: 1124 Chain: 0
# Sample: 1125 Chain: 0
# Sample: 1126 Chain: 0
# Sample: 1127 Chain: 0
# Sample: 1128 Chain: 0
# Sample: 1129 Chain: 0
# Sample: 1130 Chain: 0
# Sample: 1131 Chain: 0
# Sample: 1132 Chain: 0
# Sample: 1133 Chain: 0
# Sample: 1134 Chain: 0
# Sample: 1135 Chain: 0
# Sample: 1136 Chain: 0
# Sample: 1137 Chain: 0
# Sample: 1138 Chain: 0
# Sample: 1139 Chain: 0
# Sample: 1140 Chain: 0
# Sample: 1141 Chain: 0
# Sample: 1142 Chain: 0
# Sample: 1143 Chain: 0
# Sample: 1144 Chain: 0
# Sample: 1145 Chain: 0
# Sample: 1146 Chain: 0
# Sample: 1147 Chain: 0
# Sample: 1148 Chain: 0
# Sample: 1149 Chain: 0
# Sample: 1150 Chain: 0
# Sample: 1151 Chain: 0
# Sample: 1152 Chain: 0
# Sample: 1153 Chain: 0
# Sample: 1154 Chain: 0
# Sample: 1155 Chain: 0
# Sample: 1156 Chain: 0
# Sample: 1157 Chain: 0
# Sample: 1158 Chain: 0
# Sample: 1159 Chain: 0
# Sample: 1160 Chain: 0
# Sample: 1161 Chain: 0
# Sample: 1162 Chain: 0
# Sample: 1163 Chain: 0
# Sample: 1164 Chain: 0
# Sample: 1165 Chain: 0
# Sample: 1166 Chain: 0
# Sample: 1167 Chain: 0
# Sample: 1168 Chain: 0
# Sample: 1169 Chain: 0
# Sample: 1170 Chain: 0
# Sample: 1171 Chain: 0
# Sample: 1172 Chain: 0
# Sample: 1173 Chain: 0
# Sample: 1174 Chain: 0
# Sample: 1175 Chain: 0
# Sample: 1176 Chain: 0
# Sample: 1177 Chain: 0
# Sample: 1178 Chain: 0
# Sample: 1179 Chain: 0
# Sample: 1180 Chain: 0
# Sample: 1181 Chain: 0
# Sample: 1182 Chain: 0
# Sample: 1183 Chain: 0
# Sample: 1184 Chain: 0
# Sample: 1185 Chain: 0
# Sample: 1186 Chain: 0
# Sample: 1187 Chain: 0
# Sample: 1188 Chain: 0
# Sample: 1189 Chain: 0
# Sample: 1190 Chain: 0
# Sample: 1191 Chain: 0
# Sample: 1192 Chain: 0
# Sample: 1193 Chain: 0
# Sample: 1194 Chain: 0
# Sample: 1195 Chain: 0
# Sample: 1196 Chain: 0
# Sample: 1197 Chain: 0
# Sample: 1198 Chain: 0
# Sample: 1199 Chain: 0
# Sample: 1200 Chain: 0
# Sample: 1201 Chain: 0
# Sample: 1202 Chain: 0
# Sample: 1203 Chain: 0
# Sample: 1204 Chain: 0
# Sample: 1205 Chain: 0
# Sample: 1206 Chain: 0
# Sample: 1207 Chain: 0
# Sample: 1208 Chain: 0
# Sample: 1209 Chain: 0
# Sample: 1210 Chain: 0
# Sample: 1211 Chain: 0
# Sample: 1212 Chain: 0
# Sample: 1213 Chain: 0
# Sample: 1214 Chain: 0
# Sample: 1215 Chain: 0
# Sample: 1216 Chain: 0
# Sample: 1217 Chain: 0
# Sample: 1218 Chain: 0
# Sample: 1219 Chain: 0
# Sample: 1220 Chain: 0
# Sample: 1221 Chain: 0
# Sample: 1222 Chain: 0
# Sample: 1223 Chain: 0
# Sample: 1224 Chain: 0
# Sample: 1225 Chain: 0
# Sample: 1226 Chain: 0
# Sample: 1227 Chain: 0
# Sample: 1228 Chain: 0
# Sample: 1229 Chain: 0
# Sample: 1230 Chain: 0
# Sample: 1231 Chain: 0
# Sample: 1232 Chain: 0
# Sample: 1233 Chain: 0
# Sample: 1234 Chain: 0
# Sample: 1235 Chain: 0
# Sample: 1236 Chain: 0
# Sample: 1237 Chain: 0
# Sample: 1238 Chain: 0
# Sample: 1239 Chain: 0
# Sample: 1240 Chain: 0
# Sample: 1241 Chain: 0
# Sample: 1242 Chain: 0
# Sample: 1243 Chain: 0
# Sample: 1244 Chain: 0
# Sample: 1245 Chain: 0
# Sample: 1246 Chain: 0
# Sample: 1247 Chain: 0
# Sample: 1248 Chain: 0
# Sample: 1249 Chain: 0
# Sample: 1250 Chain: 0
# Sample: 1251 Chain: 0
# Sample: 1252 Chain: 0
# Sample: 1253 Chain: 0
# Sample: 1254 Chain: 0
# Sample: 1255 Chain: 0
# Sample: 1256 Chain: 0
# Sample: 1257 Chain: 0
# Sample: 1258 Chain: 0
# Sample: 1259 Chain: 0
# Sample: 1260 Chain: 0
# Sample: 1261 Chain: 0
# Sample: 1262 Chain: 0
# Sample: 1263 Chain: 0
# Sample: 1264 Chain: 0
# Sample: 1265 Chain: 0
# Sample: 1266 Chain: 0
# Sample: 1267 Chain: 0
# Sample: 1268 Chain: 0
# Sample: 1269 Chain: 0
# Sample: 1270 Chain: 0
# Sample: 1271 Chain: 0
# Sample: 1272 Chain: 0
# Sample: 1273 Chain: 0
# Sample: 1274 Chain: 0
# Sample: 1275 Chain: 0
# Sample: 1276 Chain: 0
# Sample: 1277 Chain: 0
# Sample: 1278 Chain: 0
# Sample: 1279 Chain: 0
# Sample: 1280 Chain: 0
# Sample: 1281 Chain: 0
# Sample: 1282 Chain: 0
# Sample: 1283 Chain: 0
# Sample: 1284 Chain: 0
# Sample: 1285 Chain: 0
# Sample: 1286 Chain: 0
# Sample: 1287 Chain: 0
# Sample: 1288 Chain: 0
# Sample: 1289 Chain: 0
# Sample: 1290 Chain: 0
# Sample: 1291 Chain: 0
# Sample: 1292 Chain: 0
# Sample: 1293 Chain: 0
# Sample: 1294 Chain: 0
# Sample: 1295 Chain: 0
# Sample: 1296 Chain: 0
# Sample: 1297 Chain: 0
# Sample: 1298 Chain: 0
# Sample: 1299 Chain: 0
# Sample: 1300 Chain: 0
# Sample: 1301 Chain: 0
# Sample: 1302 Chain: 0
# Sample: 1303 Chain: 0
# Sample: 1304 Chain: 0
# Sample: 1305 Chain: 0
# Sample: 1306 Chain: 0
# Sample: 1307 Chain: 0
# Sample: 1308 Chain: 0
# Sample: 1309 Chain: 0
# Sample: 1310 Chain: 0
# Sample: 1311 Chain: 0
# Sample: 1312 Chain: 0
# Sample: 1313 Chain: 0
# Sample: 1314 Chain: 0
# Sample: 1315 Chain: 0
# Sample: 1316 Chain: 0
# Sample: 1317 Chain: 0
# Sample: 1318 Chain: 0
# Sample: 1319 Chain: 0
# Sample: 1320 Chain: 0
# Sample: 1321 Chain: 0
# Sample: 1322 Chain: 0
# Sample: 1323 Chain: 0
# Sample: 1324 Chain: 0
# Sample: 1325 Chain: 0
# Sample: 1326 Chain: 0
# Sample: 1327 Chain: 0
# Sample: 1328 Chain: 0
# Sample: 1329 Chain: 0
# Sample: 1330 Chain: 0
# Sample: 1331 Chain: 0
# Sample: 1332 Chain: 0
# Sample: 1333 Chain: 0
# Sample: 1334 Chain: 0
# Sample: 1335 Chain: 0
# Sample: 1336 Chain: 0
# Sample: 1337 Chain: 0
# Sample: 1338 Chain: 0
# Sample: 1339 Chain: 0
# Sample: 1340 Chain: 0
# Sample: 1341 Chain: 0
# Sample: 1342 Chain: 0
# Sample: 1343 Chain: 0
# Sample: 1344 Chain: 0
# Sample: 1345 Chain: 0
# Sample: 1346 Chain: 0
# Sample: 1347 Chain: 0
# Sample: 1348 Chain: 0
# Sample: 1349 Chain: 0
# Sample: 1350 Chain: 0
# Sample: 1351 Chain: 0
# Sample: 1352 Chain: 0
# Sample: 1353 Chain: 0
# Sample: 1354 Chain: 0
# Sample: 1355 Chain: 0
# Sample: 1356 Chain: 0
# Sample: 1357 Chain: 0
# Sample: 1358 Chain: 0
# Sample: 1359 Chain: 0
# Sample: 1360 Chain: 0
# Sample: 1361 Chain: 0
# Sample: 1362 Chain: 0
# Sample: 1363 Chain: 0
# Sample: 1364 Chain: 0
# Sample: 1365 Chain: 0
# Sample: 1366 Chain: 0
# Sample: 1367 Chain: 0
# Sample: 1368 Chain: 0
# Sample: 1369 Chain: 0
# Sample: 1370 Chain: 0
# Sample: 1371 Chain: 0
# Sample: 1372 Chain: 0
# Sample: 1373 Chain: 0
# Sample: 1374 Chain: 0
# Sample: 1375 Chain: 0
# Sample: 1376 Chain: 0
# Sample: 1377 Chain: 0
# Sample: 1378 Chain: 0
# Sample: 1379 Chain: 0
# Sample: 1380 Chain: 0
# Sample: 1381 Chain: 0
# Sample: 1382 Chain: 0
# Sample: 1383 Chain: 0
# Sample: 1384 Chain: 0
# Sample: 1385 Chain: 0
# Sample: 1386 Chain: 0
# Sample: 1387 Chain: 0
# Sample: 1388 Chain: 0
# Sample: 1389 Chain: 0
# Sample: 1390 Chain: 0
# Sample: 1391 Chain: 0
# Sample: 1392 Chain: 0
# Sample: 1393 Chain: 0
# Sample: 1394 Chain: 0
# Sample: 1395 Chain: 0
# Sample: 1396 Chain: 0
# Sample: 1397 Chain: 0
# Sample: 1398 Chain: 0
# Sample: 1399 Chain: 0
# Sample: 1400 Chain: 0
# Sample: 1401 Chain: 0
# Sample: 1402 Chain: 0
# Sample: 1403 Chain: 0
# Sample: 1404 Chain: 0
# Sample: 1405 Chain: 0
# Sample: 1406 Chain: 0
# Sample: 1407 Chain: 0
# Sample: 1408 Chain: 0
# Sample: 1409 Chain: 0
# Sample: 1410 Chain: 0
# Sample: 1411 Chain: 0
# Sample: 1412 Chain: 0
# Sample: 1413 Chain: 0
# Sample: 1414 Chain: 0
# Sample: 1415 Chain: 0
# Sample: 1416 Chain: 0
# Sample: 1417 Chain: 0
# Sample: 1418 Chain: 0
# Sample: 1419 Chain: 0
# Sample: 1420 Chain: 0
# Sample: 1421 Chain: 0
# Sample: 1422 Chain: 0
# Sample: 1423 Chain: 0
# Sample: 1424 Chain: 0
# Sample: 1425 Chain: 0
# Sample: 1426 Chain: 0
# Sample: 1427 Chain: 0
# Sample: 1428 Chain: 0
# Sample: 1429 Chain: 0
# Sample: 1430 Chain: 0
# Sample: 1431 Chain: 0
# Sample: 1432 Chain: 0
# Sample: 1433 Chain: 0
# Sample: 1434 Chain: 0
# Sample: 1435 Chain: 0
# Sample: 1436 Chain: 0
# Sample: 1437 Chain: 0
# Sample: 1438 Chain: 0
# Sample: 1439 Chain: 0
# Sample: 1440 Chain: 0
# Sample: 1441 Chain: 0
# Sample: 1442 Chain: 0
# Sample: 1443 Chain: 0
# Sample: 1444 Chain: 0
# Sample: 1445 Chain: 0
# Sample: 1446 Chain: 0
# Sample: 1447 Chain: 0
# Sample: 1448 Chain: 0
# Sample: 1449 Chain: 0
# Sample: 1450 Chain: 0
# Sample: 1451 Chain: 0
# Sample: 1452 Chain: 0
# Sample: 1453 Chain: 0
# Sample: 1454 Chain: 0
# Sample: 1455 Chain: 0
# Sample: 1456 Chain: 0
# Sample: 1457 Chain: 0
# Sample: 1458 Chain: 0
# Sample: 1459 Chain: 0
# Sample: 1460 Chain: 0
# Sample: 1461 Chain: 0
# Sample: 1462 Chain: 0
# Sample: 1463 Chain: 0
# Sample: 1464 Chain: 0
# Sample: 1465 Chain: 0
# Sample: 1466 Chain: 0
# Sample: 1467 Chain: 0
# Sample: 1468 Chain: 0
# Sample: 1469 Chain: 0
# Sample: 1470 Chain: 0
# Sample: 1471 Chain: 0
# Sample: 1472 Chain: 0
# Sample: 1473 Chain: 0
# Sample: 1474 Chain: 0
# Sample: 1475 Chain: 0
# Sample: 1476 Chain: 0
# Sample: 1477 Chain: 0
# Sample: 1478 Chain: 0
# Sample: 1479 Chain: 0
# Sample: 1480 Chain: 0
# Sample: 1481 Chain: 0
# Sample: 1482 Chain: 0
# Sample: 1483 Chain: 0
# Sample: 1484 Chain: 0
# Sample: 1485 Chain: 0
# Sample: 1486 Chain: 0
# Sample: 1487 Chain: 0
# Sample: 1488 Chain: 0
# Sample: 1489 Chain: 0
# Sample: 1490 Chain: 0
# Sample: 1491 Chain: 0
# Sample: 1492 Chain: 0
# Sample: 1493 Chain: 0
# Sample: 1494 Chain: 0
# Sample: 1495 Chain: 0
# Sample: 1496 Chain: 0
# Sample: 1497 Chain: 0
# Sample: 1498 Chain: 0
# Sample: 1499 Chain: 0
# Sample: 1500 Chain: 0
# Sample: 1501 Chain: 0
# Sample: 1502 Chain: 0
# Sample: 1503 Chain: 0
# Sample: 1504 Chain: 0
# Sample: 1505 Chain: 0
# Sample: 1506 Chain: 0
# Sample: 1507 Chain: 0
# Sample: 1508 Chain: 0
# Sample: 1509 Chain: 0
# Sample: 1510 Chain: 0
# Sample: 1511 Chain: 0
# Sample: 1512 Chain: 0
# Sample: 1513 Chain: 0
# Sample: 1514 Chain: 0
# Sample: 1515 Chain: 0
# Sample: 1516 Chain: 0
# Sample: 1517 Chain: 0
# Sample: 1518 Chain: 0
# Sample: 1519 Chain: 0
# Sample: 1520 Chain: 0
# Sample: 1521 Chain: 0
# Sample: 1522 Chain: 0
# Sample: 1523 Chain: 0
# Sample: 1524 Chain: 0
# Sample: 1525 Chain: 0
# Sample: 1526 Chain: 0
# Sample: 1527 Chain: 0
# Sample: 1528 Chain: 0
# Sample: 1529 Chain: 0
# Sample: 1530 Chain: 0
# Sample: 1531 Chain: 0
# Sample: 1532 Chain: 0
# Sample: 1533 Chain: 0
# Sample: 1534 Chain: 0
# Sample: 1535 Chain: 0
# Sample: 1536 Chain: 0
# Sample: 1537 Chain: 0
# Sample: 1538 Chain: 0
# Sample: 1539 Chain: 0
# Sample: 1540 Chain: 0
# Sample: 1541 Chain: 0
# Sample: 1542 Chain: 0
# Sample: 1543 Chain: 0
# Sample: 1544 Chain: 0
# Sample: 1545 Chain: 0
# Sample: 1546 Chain: 0
# Sample: 1547 Chain: 0
# Sample: 1548 Chain: 0
# Sample: 1549 Chain: 0
# Sample: 1550 Chain: 0
# Sample: 1551 Chain: 0
# Sample: 1552 Chain: 0
# Sample: 1553 Chain: 0
# Sample: 1554 Chain: 0
# Sample: 1555 Chain: 0
# Sample: 1556 Chain: 0
# Sample: 1557 Chain: 0
# Sample: 1558 Chain: 0
# Sample: 1559 Chain: 0
# Sample: 1560 Chain: 0
# Sample: 1561 Chain: 0
# Sample: 1562 Chain: 0
# Sample: 1563 Chain: 0
# Sample: 1564 Chain: 0
# Sample: 1565 Chain: 0
# Sample: 1566 Chain: 0
# Sample: 1567 Chain: 0
# Sample: 1568 Chain: 0
# Sample: 1569 Chain: 0
# Sample: 1570 Chain: 0
# Sample: 1571 Chain: 0
# Sample: 1572 Chain: 0
# Sample: 1573 Chain: 0
# Sample: 1574 Chain: 0
# Sample: 1575 Chain: 0
# Sample: 1576 Chain: 0
# Sample: 1577 Chain: 0
# Sample: 1578 Chain: 0
# Sample: 1579 Chain: 0
# Sample: 1580 Chain: 0
# Sample: 1581 Chain: 0
# Sample: 1582 Chain: 0
# Sample: 1583 Chain: 0
# Sample: 1584 Chain: 0
# Sample: 1585 Chain: 0
# Sample: 1586 Chain: 0
# Sample: 1587 Chain: 0
# Sample: 1588 Chain: 0
# Sample: 1589 Chain: 0
# Sample: 1590 Chain: 0
# Sample: 1591 Chain: 0
# Sample: 1592 Chain: 0
# Sample: 1593 Chain: 0
# Sample: 1594 Chain: 0
# Sample: 1595 Chain: 0
# Sample: 1596 Chain: 0
# Sample: 1597 Chain: 0
# Sample: 1598 Chain: 0
# Sample: 1599 Chain: 0
# Sample: 1600 Chain: 0
# Sample: 1601 Chain: 0
# Sample: 1602 Chain: 0
# Sample: 1603 Chain: 0
# Sample: 1604 Chain: 0
# Sample: 1605 Chain: 0
# Sample: 1606 Chain: 0
# Sample: 1607 Chain: 0
# Sample: 1608 Chain: 0
# Sample: 1609 Chain: 0
# Sample: 1610 Chain: 0
# Sample: 1611 Chain: 0
# Sample: 1612 Chain: 0
# Sample: 1613 Chain: 0
# Sample: 1614 Chain: 0
# Sample: 1615 Chain: 0
# Sample: 1616 Chain: 0
# Sample: 1617 Chain: 0
# Sample: 1618 Chain: 0
# Sample: 1619 Chain: 0
# Sample: 1620 Chain: 0
# Sample: 1621 Chain: 0
# Sample: 1622 Chain: 0
# Sample: 1623 Chain: 0
# Sample: 1624 Chain: 0
# Sample: 1625 Chain: 0
# Sample: 1626 Chain: 0
# Sample: 1627 Chain: 0
# Sample: 1628 Chain: 0
# Sample: 1629 Chain: 0
# Sample: 1630 Chain: 0
# Sample: 1631 Chain: 0
# Sample: 1632 Chain: 0
# Sample: 1633 Chain: 0
# Sample: 1634 Chain: 0
# Sample: 1635 Chain: 0
# Sample: 1636 Chain: 0
# Sample: 1637 Chain: 0
# Sample: 1638 Chain: 0
# Sample: 1639 Chain: 0
# Sample: 1640 Chain: 0
# Sample: 1641 Chain: 0
# Sample: 1642 Chain: 0
# Sample: 1643 Chain: 0
# Sample: 1644 Chain: 0
# Sample: 1645 Chain: 0
# Sample: 1646 Chain: 0
# Sample: 1647 Chain: 0
# Sample: 1648 Chain: 0
# Sample: 1649 Chain: 0
# Sample: 1650 Chain: 0
# Sample: 1651 Chain: 0
# Sample: 1652 Chain: 0
# Sample: 1653 Chain: 0
# Sample: 1654 Chain: 0
# Sample: 1655 Chain: 0
# Sample: 1656 Chain: 0
# Sample: 1657 Chain: 0
# Sample: 1658 Chain: 0
# Sample: 1659 Chain: 0
# Sample: 1660 Chain: 0
# Sample: 1661 Chain: 0
# Sample: 1662 Chain: 0
# Sample: 1663 Chain: 0
# Sample: 1664 Chain: 0
# Sample: 1665 Chain: 0
# Sample: 1666 Chain: 0
# Sample: 1667 Chain: 0
# Sample: 1668 Chain: 0
# Sample: 1669 Chain: 0
# Sample: 1670 Chain: 0
# Sample: 1671 Chain: 0
# Sample: 1672 Chain: 0
# Sample: 1673 Chain: 0
# Sample: 1674 Chain: 0
# Sample: 1675 Chain: 0
# Sample: 1676 Chain: 0
# Sample: 1677 Chain: 0
# Sample: 1678 Chain: 0
# Sample: 1679 Chain: 0
# Sample: 1680 Chain: 0
# Sample: 1681 Chain: 0
# Sample: 1682 Chain: 0
# Sample: 1683 Chain: 0
# Sample: 1684 Chain: 0
# Sample: 1685 Chain: 0
# Sample: 1686 Chain: 0
# Sample: 1687 Chain: 0
# Sample: 1688 Chain: 0
# Sample: 1689 Chain: 0
# Sample: 1690 Chain: 0
# Sample: 1691 Chain: 0
# Sample: 1692 Chain: 0
# Sample: 1693 Chain: 0
# Sample: 1694 Chain: 0
# Sample: 1695 Chain: 0
# Sample: 1696 Chain: 0
# Sample: 1697 Chain: 0
# Sample: 1698 Chain: 0
# Sample: 1699 Chain: 0
# Sample: 1700 Chain: 0
# Sample: 1701 Chain: 0
# Sample: 1702 Chain: 0
# Sample: 1703 Chain: 0
# Sample: 1704 Chain: 0
# Sample: 1705 Chain: 0
# Sample: 1706 Chain: 0
# Sample: 1707 Chain: 0
# Sample: 1708 Chain: 0
# Sample: 1709 Chain: 0
# Sample: 1710 Chain: 0
# Sample: 1711 Chain: 0
# Sample: 1712 Chain: 0
# Sample: 1713 Chain: 0
# Sample: 1714 Chain: 0
# Sample: 1715 Chain: 0
# Sample: 1716 Chain: 0
# Sample: 1717 Chain: 0
# Sample: 1718 Chain: 0
# Sample: 1719 Chain: 0
# Sample: 1720 Chain: 0
# Sample: 1721 Chain: 0
# Sample: 1722 Chain: 0
# Sample: 1723 Chain: 0
# Sample: 1724 Chain: 0
# Sample: 1725 Chain: 0
# Sample: 1726 Chain: 0
# Sample: 1727 Chain: 0
# Sample: 1728 Chain: 0
# Sample: 1729 Chain: 0
# Sample: 1730 Chain: 0
# Sample: 1731 Chain: 0
# Sample: 1732 Chain: 0
# Sample: 1733 Chain: 0
# Sample: 1734 Chain: 0
# Sample: 1735 Chain: 0
# Sample: 1736 Chain: 0
# Sample: 1737 Chain: 0
# Sample: 1738 Chain: 0
# Sample: 1739 Chain: 0
# Sample: 1740 Chain: 0
# Sample: 1741 Chain: 0
# Sample: 1742 Chain: 0
# Sample: 1743 Chain: 0
# Sample: 1744 Chain: 0
# Sample: 1745 Chain: 0
# Sample: 1746 Chain: 0
# Sample: 1747 Chain: 0
# Sample: 1748 Chain: 0
# Sample: 1749 Chain: 0
# Sample: 1750 Chain: 0
# Sample: 1751 Chain: 0
# Sample: 1752 Chain: 0
# Sample: 1753 Chain: 0
# Sample: 1754 Chain: 0
# Sample: 1755 Chain: 0
# Sample: 1756 Chain: 0
# Sample: 1757 Chain: 0
# Sample: 1758 Chain: 0
# Sample: 1759 Chain: 0
# Sample: 1760 Chain: 0
# Sample: 1761 Chain: 0
# Sample: 1762 Chain: 0
# Sample: 1763 Chain: 0
# Sample: 1764 Chain: 0
# Sample: 1765 Chain: 0
# Sample: 1766 Chain: 0
# Sample: 1767 Chain: 0
# Sample: 1768 Chain: 0
# Sample: 1769 Chain: 0
# Sample: 1770 Chain: 0
# Sample: 1771 Chain: 0
# Sample: 1772 Chain: 0
# Sample: 1773 Chain: 0
# Sample: 1774 Chain: 0
# Sample: 1775 Chain: 0
# Sample: 1776 Chain: 0
# Sample: 1777 Chain: 0
# Sample: 1778 Chain: 0
# Sample: 1779 Chain: 0
# Sample: 1780 Chain: 0
# Sample: 1781 Chain: 0
# Sample: 1782 Chain: 0
# Sample: 1783 Chain: 0
# Sample: 1784 Chain: 0
# Sample: 1785 Chain: 0
# Sample: 1786 Chain: 0
# Sample: 1787 Chain: 0
# Sample: 1788 Chain: 0
# Sample: 1789 Chain: 0
# Sample: 1790 Chain: 0
# Sample: 1791 Chain: 0
# Sample: 1792 Chain: 0
# Sample: 1793 Chain: 0
# Sample: 1794 Chain: 0
# Sample: 1795 Chain: 0
# Sample: 1796 Chain: 0
# Sample: 1797 Chain: 0
# Sample: 1798 Chain: 0
# Sample: 1799 Chain: 0
# Sample: 1800 Chain: 0
# Sample: 1801 Chain: 0
# Sample: 1802 Chain: 0
# Sample: 1803 Chain: 0
# Sample: 1804 Chain: 0
# Sample: 1805 Chain: 0
# Sample: 1806 Chain: 0
# Sample: 1807 Chain: 0
# Sample: 1808 Chain: 0
# Sample: 1809 Chain: 0
# Sample: 1810 Chain: 0
# Sample: 1811 Chain: 0
# Sample: 1812 Chain: 0
# Sample: 1813 Chain: 0
# Sample: 1814 Chain: 0
# Sample: 1815 Chain: 0
# Sample: 1816 Chain: 0
# Sample: 1817 Chain: 0
# Sample: 1818 Chain: 0
# Sample: 1819 Chain: 0
# Sample: 1820 Chain: 0
# Sample: 1821 Chain: 0
# Sample: 1822 Chain: 0
# Sample: 1823 Chain: 0
# Sample: 1824 Chain: 0
# Sample: 1825 Chain: 0
# Sample: 1826 Chain: 0
# Sample: 1827 Chain: 0
# Sample: 1828 Chain: 0
# Sample: 1829 Chain: 0
# Sample: 1830 Chain: 0
# Sample: 1831 Chain: 0
# Sample: 1832 Chain: 0
# Sample: 1833 Chain: 0
# Sample: 1834 Chain: 0
# Sample: 1835 Chain: 0
# Sample: 1836 Chain: 0
# Sample: 1837 Chain: 0
# Sample: 1838 Chain: 0
# Sample: 1839 Chain: 0
# Sample: 1840 Chain: 0
# Sample: 1841 Chain: 0
# Sample: 1842 Chain: 0
# Sample: 1843 Chain: 0
# Sample: 1844 Chain: 0
# Sample: 1845 Chain: 0
# Sample: 1846 Chain: 0
# Sample: 1847 Chain: 0
# Sample: 1848 Chain: 0
# Sample: 1849 Chain: 0
# Sample: 1850 Chain: 0
# Sample: 1851 Chain: 0
# Sample: 1852 Chain: 0
# Sample: 1853 Chain: 0
# Sample: 1854 Chain: 0
# Sample: 1855 Chain: 0
# Sample: 1856 Chain: 0
# Sample: 1857 Chain: 0
# Sample: 1858 Chain: 0
# Sample: 1859 Chain: 0
# Sample: 1860 Chain: 0
# Sample: 1861 Chain: 0
# Sample: 1862 Chain: 0
# Sample: 1863 Chain: 0
# Sample: 1864 Chain: 0
# Sample: 1865 Chain: 0
# Sample: 1866 Chain: 0
# Sample: 1867 Chain: 0
# Sample: 1868 Chain: 0
# Sample: 1869 Chain: 0
# Sample: 1870 Chain: 0
# Sample: 1871 Chain: 0
# Sample: 1872 Chain: 0
# Sample: 1873 Chain: 0
# Sample: 1874 Chain: 0
# Sample: 1875 Chain: 0
# Sample: 1876 Chain: 0
# Sample: 1877 Chain: 0
# Sample: 1878 Chain: 0
# Sample: 1879 Chain: 0
# Sample: 1880 Chain: 0
# Sample: 1881 Chain: 0
# Sample: 1882 Chain: 0
# Sample: 1883 Chain: 0
# Sample: 1884 Chain: 0
# Sample: 1885 Chain: 0
# Sample: 1886 Chain: 0
# Sample: 1887 Chain: 0
# Sample: 1888 Chain: 0
# Sample: 1889 Chain: 0
# Sample: 1890 Chain: 0
# Sample: 1891 Chain: 0
# Sample: 1892 Chain: 0
# Sample: 1893 Chain: 0
# Sample: 1894 Chain: 0
# Sample: 1895 Chain: 0
# Sample: 1896 Chain: 0
# Sample: 1897 Chain: 0
# Sample: 1898 Chain: 0
# Sample: 1899 Chain: 0
# Sample: 1900 Chain: 0
# Sample: 1901 Chain: 0
# Sample: 1902 Chain: 0
# Sample: 1903 Chain: 0
# Sample: 1904 Chain: 0
# Sample: 1905 Chain: 0
# Sample: 1906 Chain: 0
# Sample: 1907 Chain: 0
# Sample: 1908 Chain: 0
# Sample: 1909 Chain: 0
# Sample: 1910 Chain: 0
# Sample: 1911 Chain: 0
# Sample: 1912 Chain: 0
# Sample: 1913 Chain: 0
# Sample: 1914 Chain: 0
# Sample: 1915 Chain: 0
# Sample: 1916 Chain: 0
# Sample: 1917 Chain: 0
# Sample: 1918 Chain: 0
# Sample: 1919 Chain: 0
# Sample: 1920 Chain: 0
# Sample: 1921 Chain: 0
# Sample: 1922 Chain: 0
# Sample: 1923 Chain: 0
# Sample: 1924 Chain: 0
# Sample: 1925 Chain: 0
# Sample: 1926 Chain: 0
# Sample: 1927 Chain: 0
# Sample: 1928 Chain: 0
# Sample: 1929 Chain: 0
# Sample: 1930 Chain: 0
# Sample: 1931 Chain: 0
# Sample: 1932 Chain: 0
# Sample: 1933 Chain: 0
# Sample: 1934 Chain: 0
# Sample: 1935 Chain: 0
# Sample: 1936 Chain: 0
# Sample: 1937 Chain: 0
# Sample: 1938 Chain: 0
# Sample: 1939 Chain: 0
# Sample: 1940 Chain: 0
# Sample: 1941 Chain: 0
# Sample: 1942 Chain: 0
# Sample: 1943 Chain: 0
# Sample: 1944 Chain: 0
# Sample: 1945 Chain: 0
# Sample: 1946 Chain: 0
# Sample: 1947 Chain: 0
# Sample: 1948 Chain: 0
# Sample: 1949 Chain: 0
# Sample: 1950 Chain: 0
# Sample: 1951 Chain: 0
# Sample: 1952 Chain: 0
# Sample: 1953 Chain: 0
# Sample: 1954 Chain: 0
# Sample: 1955 Chain: 0
# Sample: 1956 Chain: 0
# Sample: 1957 Chain: 0
# Sample: 1958 Chain: 0
# Sample: 1959 Chain: 0
# Sample: 1960 Chain: 0
# Sample: 1961 Chain: 0
# Sample: 1962 Chain: 0
# Sample: 1963 Chain: 0
# Sample: 1964 Chain: 0
# Sample: 1965 Chain: 0
# Sample: 1966 Chain: 0
# Sample: 1967 Chain: 0
# Sample: 1968 Chain: 0
# Sample: 1969 Chain: 0
# Sample: 1970 Chain: 0
# Sample: 1971 Chain: 0
# Sample: 1972 Chain: 0
# Sample: 1973 Chain: 0
# Sample: 1974 Chain: 0
# Sample: 1975 Chain: 0
# Sample: 1976 Chain: 0
# Sample: 1977 Chain: 0
# Sample: 1978 Chain: 0
# Sample: 1979 Chain: 0
# Sample: 1980 Chain: 0
# Sample: 1981 Chain: 0
# Sample: 1982 Chain: 0
# Sample: 1983 Chain: 0
# Sample: 1984 Chain: 0
# Sample: 1985 Chain: 0
# Sample: 1986 Chain: 0
# Sample: 1987 Chain: 0
# Sample: 1988 Chain: 0
# Sample: 1989 Chain: 0
# Sample: 1990 Chain: 0
# Sample: 1991 Chain: 0
# Sample: 1992 Chain: 0
# Sample: 1993 Chain: 0
# Sample: 1994 Chain: 0
# Sample: 1995 Chain: 0
# Sample: 1996 Chain: 0
# Sample: 1997 Chain: 0
# Sample: 1998 Chain: 0
# Sample: 1999 Chain: 0
# Sample: 2000 Chain: 0
# Sample: 2001 Chain: 0
# Sample: 2002 Chain: 0
# Sample: 2003 Chain: 0
# Sample: 2004 Chain: 0
# Sample: 2005 Chain: 0
# Sample: 2006 Chain: 0
# Sample: 2007 Chain: 0
# Sample: 2008 Chain: 0
# Sample: 2009 Chain: 0
# Sample: 2010 Chain: 0
# Sample: 2011 Chain: 0
# Sample: 2012 Chain: 0
# Sample: 2013 Chain: 0
# Sample: 2014 Chain: 0
# Sample: 2015 Chain: 0
# Sample: 2016 Chain: 0
# Sample: 2017 Chain: 0
# Sample: 2018 Chain: 0
# Sample: 2019 Chain: 0
# Sample: 2020 Chain: 0
# Sample: 2021 Chain: 0
# Sample: 2022 Chain: 0
# Sample: 2023 Chain: 0
# Sample: 2024 Chain: 0
# Sample: 2025 Chain: 0
# Sample: 2026 Chain: 0
# Sample: 2027 Chain: 0
# Sample: 2028 Chain: 0
# Sample: 2029 Chain: 0
# Sample: 2030 Chain: 0
# Sample: 2031 Chain: 0
# Sample: 2032 Chain: 0
# Sample: 2033 Chain: 0
# Sample: 2034 Chain: 0
# Sample: 2035 Chain: 0
# Sample: 2036 Chain: 0
# Sample: 2037 Chain: 0
# Sample: 2038 Chain: 0
# Sample: 2039 Chain: 0
# Sample: 2040 Chain: 0
# Sample: 2041 Chain: 0
# Sample: 2042 Chain: 0
# Sample: 2043 Chain: 0
# Sample: 2044 Chain: 0
# Sample: 2045 Chain: 0
# Sample: 2046 Chain: 0
# Sample: 2047 Chain: 0
# Sample: 2048 Chain: 0
# Sample: 2049 Chain: 0
# Sample: 2050 Chain: 0
# Sample: 2051 Chain: 0
# Sample: 2052 Chain: 0
# Sample: 2053 Chain: 0
# Sample: 2054 Chain: 0
# Sample: 2055 Chain: 0
# Sample: 2056 Chain: 0
# Sample: 2057 Chain: 0
# Sample: 2058 Chain: 0
# Sample: 2059 Chain: 0
# Sample: 2060 Chain: 0
# Sample: 2061 Chain: 0
# Sample: 2062 Chain: 0
# Sample: 2063 Chain: 0
# Sample: 2064 Chain: 0
# Sample: 2065 Chain: 0
# Sample: 2066 Chain: 0
# Sample: 2067 Chain: 0
# Sample: 2068 Chain: 0
# Sample: 2069 Chain: 0
# Sample: 2070 Chain: 0
# Sample: 2071 Chain: 0
# Sample: 2072 Chain: 0
# Sample: 2073 Chain: 0
# Sample: 2074 Chain: 0
# Sample: 2075 Chain: 0
# Sample: 2076 Chain: 0
# Sample: 2077 Chain: 0
# Sample: 2078 Chain: 0
# Sample: 2079 Chain: 0
# Sample: 2080 Chain: 0
# Sample: 2081 Chain: 0
# Sample: 2082 Chain: 0
# Sample: 2083 Chain: 0
# Sample: 2084 Chain: 0
# Sample: 2085 Chain: 0
# Sample: 2086 Chain: 0
# Sample: 2087 Chain: 0
# Sample: 2088 Chain: 0
# Sample: 2089 Chain: 0
# Sample: 2090 Chain: 0
# Sample: 2091 Chain: 0
# Sample: 2092 Chain: 0
# Sample: 2093 Chain: 0
# Sample: 2094 Chain: 0
# Sample: 2095 Chain: 0
# Sample: 2096 Chain: 0
# Sample: 2097 Chain: 0
# Sample: 2098 Chain: 0
# Sample: 2099 Chain: 0
# Sample: 2100 Chain: 0
# Sample: 2101 Chain: 0
# Sample: 2102 Chain: 0
# Sample: 2103 Chain: 0
# Sample: 2104 Chain: 0
# Sample: 2105 Chain: 0
# Sample: 2106 Chain: 0
# Sample: 2107 Chain: 0
# Sample: 2108 Chain: 0
# Sample: 2109 Chain: 0
# Sample: 2110 Chain: 0
# Sample: 2111 Chain: 0
# Sample: 2112 Chain: 0
# Sample: 2113 Chain: 0
# Sample: 2114 Chain: 0
# Sample: 2115 Chain: 0
# Sample: 2116 Chain: 0
# Sample: 2117 Chain: 0
# Sample: 2118 Chain: 0
# Sample: 2119 Chain: 0
# Sample: 2120 Chain: 0
# Sample: 2121 Chain: 0
# Sample: 2122 Chain: 0
# Sample: 2123 Chain: 0
# Sample: 2124 Chain: 0
# Sample: 2125 Chain: 0
# Sample: 2126 Chain: 0
# Sample: 2127 Chain: 0
# Sample: 2128 Chain: 0
# Sample: 2129 Chain: 0
# Sample: 2130 Chain: 0
# Sample: 2131 Chain: 0
# Sample: 2132 Chain: 0
# Sample: 2133 Chain: 0
# Sample: 2134 Chain: 0
# Sample: 2135 Chain: 0
# Sample: 2136 Chain: 0
# Sample: 2137 Chain: 0
# Sample: 2138 Chain: 0
# Sample: 2139 Chain: 0
# Sample: 2140 Chain: 0
# Sample: 2141 Chain: 0
# Sample: 2142 Chain: 0
# Sample: 2143 Chain: 0
# Sample: 2144 Chain: 0
# Sample: 2145 Chain: 0
# Sample: 2146 Chain: 0
# Sample: 2147 Chain: 0
# Sample: 2148 Chain: 0
# Sample: 2149 Chain: 0
# Sample: 2150 Chain: 0
# Sample: 2151 Chain: 0
# Sample: 2152 Chain: 0
# Sample: 2153 Chain: 0
# Sample: 2154 Chain: 0
# Sample: 2155 Chain: 0
# Sample: 2156 Chain: 0
# Sample: 2157 Chain: 0
# Sample: 2158 Chain: 0
# Sample: 2159 Chain: 0
# Sample: 2160 Chain: 0
# Sample: 2161 Chain: 0
# Sample: 2162 Chain: 0
# Sample: 2163 Chain: 0
# Sample: 2164 Chain: 0
# Sample: 2165 Chain: 0
# Sample: 2166 Chain: 0
# Sample: 2167 Chain: 0
# Sample: 2168 Chain: 0
# Sample: 2169 Chain: 0
# Sample: 2170 Chain: 0
# Sample: 2171 Chain: 0
# Sample: 2172 Chain: 0
# Sample: 2173 Chain: 0
# Sample: 2174 Chain: 0
# Sample: 2175 Chain: 0
# Sample: 2176 Chain: 0
# Sample: 2177 Chain: 0
# Sample: 2178 Chain: 0
# Sample: 2179 Chain: 0
# Sample: 2180 Chain: 0
# Sample: 2181 Chain: 0
# Sample: 2182 Chain: 0
# Sample: 2183 Chain: 0
# Sample: 2184 Chain: 0
# Sample: 2185 Chain: 0
# Sample: 2186 Chain: 0
# Sample: 2187 Chain: 0
# Sample: 2188 Chain: 0
# Sample: 2189 Chain: 0
# Sample: 2190 Chain: 0
# Sample: 2191 Chain: 0
# Sample: 2192 Chain: 0
# Sample: 2193 Chain: 0
# Sample: 2194 Chain: 0
# Sample: 2195 Chain: 0
# Sample: 2196 Chain: 0
# Sample: 2197 Chain: 0
# Sample: 2198 Chain: 0
# Sample: 2199 Chain: 0
# Sample: 2200 Chain: 0
# Sample: 2201 Chain: 0
# Sample: 2202 Chain: 0
# Sample: 2203 Chain: 0
# Sample: 2204 Chain: 0
# Sample: 2205 Chain: 0
# Sample: 2206 Chain: 0
# Sample: 2207 Chain: 0
# Sample: 2208 Chain: 0
# Sample: 2209 Chain: 0
# Sample: 2210 Chain: 0
# Sample: 2211 Chain: 0
# Sample: 2212 Chain: 0
# Sample: 2213 Chain: 0
# Sample: 2214 Chain: 0
# Sample: 2215 Chain: 0
# Sample: 2216 Chain: 0
# Sample: 2217 Chain: 0
# Sample: 2218 Chain: 0
# Sample: 2219 Chain: 0
# Sample: 2220 Chain: 0
# Sample: 2221 Chain: 0
# Sample: 2222 Chain: 0
# Sample: 2223 Chain: 0
# Sample: 2224 Chain: 0
# Sample: 2225 Chain: 0
# Sample: 2226 Chain: 0
# Sample: 2227 Chain: 0
# Sample: 2228 Chain: 0
# Sample: 2229 Chain: 0
# Sample: 2230 Chain: 0
# Sample: 2231 Chain: 0
# Sample: 2232 Chain: 0
# Sample: 2233 Chain: 0
# Sample: 2234 Chain: 0
# Sample: 2235 Chain: 0
# Sample: 2236 Chain: 0
# Sample: 2237 Chain: 0
# Sample: 2238 Chain: 0
# Sample: 2239 Chain: 0
# Sample: 2240 Chain: 0
# Sample: 2241 Chain: 0

# %%
for ss in np.arange(0,chains,1):
    subdat = hnn_fin[ss,burn:N,:]
    subacc = hnn_accept[ss,burn:N]

    accpt = subdat[subacc==1,:]

# %%
accpt.shape
# Out:
# (2468, 1)

# %%
plt.hist(accpt,bins=25)
# Out:
# (array([  5.,   8.,  33.,  65.,  95.,  91., 152., 253., 287., 170., 110.,
#          59.,  30.,  16.,  24.,  43., 103., 138., 142., 147., 249., 162.,
#          53.,  17.,  16.]),
#  array([-2.16581088, -2.00775037, -1.84968986, -1.69162934, -1.53356883,
#         -1.37550832, -1.2174478 , -1.05938729, -0.90132678, -0.74326627,
#         -0.58520575, -0.42714524, -0.26908473, -0.11102421,  0.0470363 ,
#          0.20509681,  0.36315733,  0.52121784,  0.67927835,  0.83733887,
#          0.99539938,  1.15345989,  1.31152041,  1.46958092,  1.62764143,
#          1.78570194]),
#  <BarContainer object of 25 artists>)
